# %%
a = 334
b = 33.54
c = "codingal"
d = True

print("Type of interger example: ", type(a))
print("Type of float example: ", type(b))
print("Type of string example: ", type(c))
print("Type of boolean example: ", type(d))
# Out:
# Type of interger example:  <class 'int'>
# Type of float example:  <class 'float'>
# Type of string example:  <class 'str'>
# Type of boolean example:  <class 'bool'>
