# %% [markdown]
# <a href="https://colab.research.google.com/github/muntasir2k17-coder/python/blob/main/Typecasting.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x = "Al-Muntasir"
a = 10
is_student = True
weight = 37.89

print("name ", x)
print("type of x ", type(x))
print("name ", a)
print("type of a ", type(a))
print("is_student ", is_student)
print("type of is_student", type(is_student))
print("weight ", weight)
print("Type of weigth ", type(weight))

# Typecasting

a = str(a)
print(a)
print("Type of age is ", type(a))
weight = int(weight)
print(weight)
print("Type of weight is ", type(weight))
# Out:
# name  Al-Muntasir
# type of x  <class 'str'>
# name  10
# type of a  <class 'int'>
# is_student  True
# type of is_student <class 'bool'>
# weight  37.89
# Type of weigth  <class 'float'>
# 10
# Type of age is  <class 'str'>
# 37
# Type of weight is  <class 'int'>
