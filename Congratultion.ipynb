# %% [markdown]
# <a href="https://colab.research.google.com/github/muntasir2k17-coder/python/blob/main/Congratultion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Variable

a = str(input("Write I have got 100 out of 100 \n\n"))
b = "Congratulations"

print(b)
# Out:
# Write I have got 100 out of 100
#
# po
# Congratulations
