# %% [markdown]
# <a href="https://colab.research.google.com/github/muntasir2k17-coder/python/blob/main/Marks.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Enter the marks of 4 Subjects: ")

Bangla = int(input("Enter the marks of Bangla:"))
English = int(input("Enter the marks of English:"))
Math = int(input("Enter the marks of Math:"))
Islam = int(input("Enter the marks of Islam:"))

# Sum of 4 Subjects

sum = Bangla+English+Math+Islam

print("The sum of 4 subjects is ", sum)

prc = (sum/400)*100

print(end = "percentage Mark")

print(prc)
# Out:
# Enter the marks of 4 Subjects:
# Enter the marks of Bangla:55
# Enter the marks of English:54
# Enter the marks of Math:6
# Enter the marks of Islam:4
# The sum of 4 subjects is  119
# percentage Mark29.75
