# %% [markdown]
# <a href="https://colab.research.google.com/github/muntasir2k17-coder/python/blob/main/Average.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
tree1 = 234
tree2 = 34
tree3 = 74
tree4 = 45
tree5 = 78
sum = tree1+tree2+tree3+tree4+tree5

print("The sum of total numbers is ", sum)

Average = sum/5

print(Average)
# Out:
# The sum of total numbers is  465
# 93.0
